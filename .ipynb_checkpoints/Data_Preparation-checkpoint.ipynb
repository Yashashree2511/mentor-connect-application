# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /Users/abhimhatre/miniforge3/lib/python3.10/site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /Users/abhimhatre/miniforge3/lib/python3.10/site-packages (from openpyxl) (2.0.0)

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("mentor_dataset_realistic_10000.xlsx")

df.head()
# Out:
#      name              domain                                          skills  \
# 0  User_0  Mobile Development                          Flutter, Kotlin, Swift
# 1  User_1     Career Guidance  Interview Prep, Resume Building, Career Switch
# 2  User_2  Mobile Development                          Flutter, Swift, Kotlin
# 3  User_3             Startup          Leadership, Growth, Product Management
# 4  User_4             Startup          Product Management, Growth, Leadership
#
#                              company_history  experience_years  \
# 0                           Infosys → Google                 1
# 1                             TCS → StartupX                 8
# 2                Flipkart → Amazon → Netflix                 9
# 3                       Flipkart → Accenture                 5
# 4  Netflix → TCS → Amazon → Accenture → Meta                 6
#
#                                                  bio  \
# 0  📈 Mobile Development specialist | Flutter | He...
# 1  🎯 Career Guidance specialist | Interview Prep ...
# 2  💡 Mobile Development specialist | Swift | Help...
# 3  💡 Startup specialist | Product Management | He...
# 4  🚀 Startup specialist | Leadership | Helping ot...
#
#                                          description
# 0  I am a mobile development professional with 1+...
# 1  I am a career guidance professional with 8+ ye...
# 2  I am a mobile development professional with 9+...
# 3  I am a startup professional with 5+ years of e...
# 4  I am a startup professional with 6+ years of e...

# %%
# Remove extra spaces
df = df.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

# %%
# Convert to lowercase
df = df.apply(lambda x: x.str.lower() if x.dtype == "object" else x)

# %%
# Remove duplicates
df.drop_duplicates(inplace=True)

# %%
# Clean skills column
df['skills'] = df['skills'].apply(
    lambda x: ','.join(set([i.strip() for i in str(x).split(',')])) if pd.notnull(x) else x
)

# %%
# Handle missing values
df.dropna(subset=['domain', 'skills'], inplace=True)

df['bio'].fillna('unknown', inplace=True)
df['description'].fillna('unknown', inplace=True)
df['company_history'].fillna('unknown', inplace=True)

# %%
# Remove junk characters
df.replace(r'[^a-zA-Z0-9, .+]', '', regex=True, inplace=True)

# %%
# ---------------- FEATURE ENGINEERING ---------------- #

df['combined_text'] = (
    "domain: " + df['domain'].astype(str) + ". " +
    "skills: " + df['skills'].astype(str) + ". " +
    "experience: " + df['experience_years'].astype(str) + " years. " +
    "worked at: " + df['company_history'].astype(str) + ". " +
    "bio: " + df['bio'].astype(str) + ". " +
    "description: " + df['description'].astype(str)
)

# %%
# ---------------- ENRICHMENT ---------------- #

def enrich(text):
    if "programming" in text:
        text += " software development coding backend apis"
    if "data science" in text:
        text += " machine learning ai analytics python"
    if "devops" in text:
        text += " ci cd docker kubernetes cloud"
    if "mobile development" in text:
        text += " android ios flutter react native"
    return text

df['combined_text'] = df['combined_text'].apply(enrich)

# %%
df.to_csv("cleaned_mentor_data.csv", index=False)

# %%
# !pip install sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in /Users/abhimhatre/miniforge3/lib/python3.10/site-packages (5.3.0)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in /Users/abhimhatre/miniforge3/lib/python3.10/site-packages (from sentence-transformers) (5.3.0)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /Users/abhimhatre/miniforge3/lib/python3.10/site-packages (from sentence-transformers) (1.8.0)
# Requirement already satisfied: torch>=1.11.0 in /Users/abhimhatre/miniforge3/lib/python3.10/site-packages (from sentence-transformers) (2.11.0)
# Requirement already satisfied: numpy in /Users/abhimhatre/miniforge3/lib/python3.10/site-packages (from sentence-transformers) (1.23.5)
# Requirement already satisfied: scikit-learn in /Users/abhimhatre/miniforge3/lib/python3.10/site-packages (from sentence-transformers) (1.3.0)
# Requirement already satisfied: scipy in /Users/abhimhatre/miniforge3/lib/python3.10/site-packages (from sentence-transformers) (1.10.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in /Users/abhimhatre/miniforge3/lib/python3.10/site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: tqdm in /Users/abhimhatre/miniforge3/lib/python3.10/site-packages (from sentence-transformers) (4.65.0)
# Requirement already satisfied: packaging>=20.0 in /Users/abhimhatre/miniforge3/lib/python3.10/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/abhimhatre/miniforge3/lib/python3.10/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /Users/abhimhatre/miniforge3/lib/python3.10/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2023.3.23)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/abhimhatre/miniforge3/lib/python3.10/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.2)
# Requirement already satisfied: typer in /Users/abhimhatre/miniforge3/lib/python3.10/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.24.1)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/abhimhatre/miniforge3/lib/python3.10/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: filelock>=3.10.0 in /Users/abhimhatre/miniforge3/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/abhimhatre/miniforge3/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /Users/abhimhatre/miniforge3/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/abhimhatre/miniforge3/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (0.28.1)
# Requirement already satisfied: anyio in /Users/abhimhatre/miniforge3/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (3.7.1)
# Requirement already satisfied: certifi in /Users/abhimhatre/miniforge3/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /Users/abhimhatre/miniforge3/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (1.0.9)
# Requirement already satisfied: idna in /Users/abhimhatre/miniforge3/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (3.4)
# Requirement already satisfied: h11>=0.16 in /Users/abhimhatre/miniforge3/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (0.16.0)
# Requirement already satisfied: setuptools<82 in /Users/abhimhatre/miniforge3/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (65.6.3)
# Requirement already satisfied: sympy>=1.13.3 in /Users/abhimhatre/miniforge3/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/abhimhatre/miniforge3/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/abhimhatre/miniforge3/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/abhimhatre/miniforge3/lib/python3.10/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/abhimhatre/miniforge3/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (1.2.0)
# Requirement already satisfied: exceptiongroup in /Users/abhimhatre/miniforge3/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/abhimhatre/miniforge3/lib/python3.10/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.1)
# Requirement already satisfied: joblib>=1.1.1 in /Users/abhimhatre/miniforge3/lib/python3.10/site-packages (from scikit-learn->sentence-transformers) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/abhimhatre/miniforge3/lib/python3.10/site-packages (from scikit-learn->sentence-transformers) (2.2.0)
# Requirement already satisfied: click>=8.2.1 in /Users/abhimhatre/miniforge3/lib/python3.10/site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/abhimhatre/miniforge3/lib/python3.10/site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /Users/abhimhatre/miniforge3/lib/python3.10/site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (14.3.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/abhimhatre/miniforge3/lib/python3.10/site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/abhimhatre/miniforge3/lib/python3.10/site-packages (from rich>=12.3.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/abhimhatre/miniforge3/lib/python3.10/site-packages (from rich>=12.3.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/abhimhatre/miniforge3/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (0.1.2)

# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# %%
model = SentenceTransformer('all-MiniLM-L6-v2')
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
embeddings = model.encode(df['combined_text'].tolist(), show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/313 [00:00<?, ?it/s]

# %%
def recommend_mentors(query, top_n=5):
    
    # Convert query to embedding
    query_embedding = model.encode([query])
    
    # Compute similarity
    similarity = cosine_similarity(query_embedding, embeddings)
    
    # Get top matches
    top_indices = np.argsort(similarity[0])[::-1][:top_n]
    
    # Fetch results
    results = df.iloc[top_indices][
        ['name', 'domain', 'skills', 'experience_years', 'company_history']
    ].copy()
    
    # Add similarity score
    results['similarity_score'] = similarity[0][top_indices]
    
    return results

# %%
recommend_mentors("backend developer with java")
# Out:
#           name       domain                    skills  experience_years  \
# 3078  user3078  programming  node.js,spring boot,java                15
# 8043  user8043  programming  node.js,spring boot,java                 7
# 7152  user7152  programming  node.js,spring boot,java                13
# 7425  user7425  programming  node.js,spring boot,java                 5
# 6672  user6672  programming  node.js,spring boot,java                 4
#
#                               company_history  similarity_score
# 3078  microsoft  tcs  infosys  flipkart  meta          0.528472
# 8043         amazon  flipkart  tcs  microsoft          0.518630
# 7152   tcs  startupx  netflix  meta  flipkart          0.518598
# 7425   flipkart  startupx  infosys  accenture          0.517374
# 6672        microsoft  flipkart  google  meta          0.517296

# %%
recommend_mentors("machine learning engineer")
# Out:
#           name domain                                          skills  \
# 6797  user6797   aiml  deep learning,computer vision,machine learning
# 3833  user3833   aiml  deep learning,computer vision,machine learning
# 1197  user1197   aiml  deep learning,computer vision,machine learning
# 7684  user7684   aiml  deep learning,computer vision,machine learning
# 4079  user4079   aiml  deep learning,computer vision,machine learning
#
#       experience_years                         company_history  \
# 6797                11                microsoft  tcs  flipkart
# 3833                 2  flipkart  tcs  google  meta  microsoft
# 1197                15    google  microsoft  flipkart  infosys
# 7684                12                     flipkart  tcs  meta
# 4079                 2                     flipkart  accenture
#
#       similarity_score
# 6797          0.549175
# 3833          0.545736
# 1197          0.545099
# 7684          0.544968
# 4079          0.544706

# %%
df['mentor_id'] = range(len(df))

# %%
df['rating'] = np.random.uniform(3.5, 5.0, len(df))

# %%
df.head()
# Out:
#     name              domain                                        skills  \
# 0  user0  mobile development                          flutter,kotlin,swift
# 1  user1     career guidance  career switch,resume building,interview prep
# 2  user2  mobile development                          flutter,kotlin,swift
# 3  user3             startup          growth,product management,leadership
# 4  user4             startup          growth,product management,leadership
#
#                          company_history  experience_years  \
# 0                        infosys  google                 1
# 1                          tcs  startupx                 8
# 2              flipkart  amazon  netflix                 9
# 3                    flipkart  accenture                 5
# 4  netflix  tcs  amazon  accenture  meta                 6
#
#                                                  bio  \
# 0   mobile development specialist  flutter  helpi...
# 1   career guidance specialist  interview prep  h...
# 2   mobile development specialist  swift  helping...
# 3   startup specialist  product management  helpi...
# 4   startup specialist  leadership  helping other...
#
#                                          description  \
# 0  i am a mobile development professional with 1+...
# 1  i am a career guidance professional with 8+ ye...
# 2  i am a mobile development professional with 9+...
# 3  i am a startup professional with 5+ years of e...
# 4  i am a startup professional with 6+ years of e...
#
#                                        combined_text  mentor_id    rating
# 0  domain: mobile development. skills: flutter,ko...          0  4.864801
# 1  domain: career guidance. skills: career switch...          1  4.671418
# 2  domain: mobile development. skills: flutter,ko...          2  4.768389
# 3  domain: startup. skills: growth,product manage...          3  4.070072
# 4  domain: startup. skills: growth,product manage...          4  3.644223

# %%
# !conda install -c conda-forge faiss-cpu -y
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.3.1
#   latest version: 26.1.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=26.1.1
#
#
#
# # All requested packages already installed.

# %%
import faiss
import numpy as np

# convert embeddings to numpy
embeddings_np = np.array(embeddings)

# normalize
embeddings_np = embeddings_np / np.linalg.norm(embeddings_np, axis=1, keepdims=True)

# create index
dimension = embeddings_np.shape[1]
index = faiss.IndexFlatIP(dimension)

# add data
index.add(embeddings_np)

# %%
query = "machine learning mentor"

query_embedding = model.encode([query])

# convert to numpy
query_embedding = np.array(query_embedding)

# normalize
query_embedding = query_embedding / np.linalg.norm(query_embedding, axis=1, keepdims=True)

# search top 5
D, I = index.search(query_embedding, 5)

# %%
import faiss

faiss.write_index(index, "faiss_index.bin")

# %%
import pickle

id_mapping = df['mentor_id'].tolist()

with open("id_mapping.pkl", "wb") as f:
    pickle.dump(id_mapping, f)

# %%
df.to_csv("cleaned_data_v2.csv", index=False)

# %%
index = faiss.read_index("faiss_index.bin")

# %%
with open("id_mapping.pkl", "rb") as f:
    id_mapping = pickle.load(f)

# %%
D, I = index.search(query_embedding, 5)

# %%
mentor_ids = [id_mapping[i] for i in I[0]]
mentor_ids
# Out:
# [9159, 6797, 7684, 5804, 2428]

# %%
df[df['mentor_id'].isin(mentor_ids)]
# Out:
#           name domain                                          skills  \
# 2428  user2428   aiml  deep learning,computer vision,machine learning
# 5804  user5804   aiml  deep learning,computer vision,machine learning
# 6797  user6797   aiml  deep learning,computer vision,machine learning
# 7684  user7684   aiml  deep learning,computer vision,machine learning
# 9159  user9159   aiml  deep learning,computer vision,machine learning
#
#                            company_history  experience_years  \
# 2428                      google  flipkart                14
# 5804  microsoft  flipkart  google  netflix                12
# 6797              microsoft  tcs  flipkart                11
# 7684                   flipkart  tcs  meta                12
# 9159                       microsoft  meta                 9
#
#                                                     bio  \
# 2428   aiml specialist  machine learning  helping ot...
# 5804   aiml specialist  machine learning  helping ot...
# 6797   aiml specialist  machine learning  helping ot...
# 7684   aiml specialist  machine learning  helping ot...
# 9159   aiml specialist  machine learning  helping ot...
#
#                                             description  \
# 2428  i am a aiml professional with 14+ years of exp...
# 5804  i am a aiml professional with 12+ years of exp...
# 6797  i am a aiml professional with 11+ years of exp...
# 7684  i am a aiml professional with 12+ years of exp...
# 9159  i am a aiml professional with 9+ years of expe...
#
#                                           combined_text  mentor_id    rating
# 2428  domain: aiml. skills: deep learning,computer v...       2428  4.803251
# 5804  domain: aiml. skills: deep learning,computer v...       5804  3.517258
# 6797  domain: aiml. skills: deep learning,computer v...       6797  4.553049
# 7684  domain: aiml. skills: deep learning,computer v...       7684  4.734890
# 9159  domain: aiml. skills: deep learning,computer v...       9159  3.994943

# %%
import os
os.getcwd()
# Out:
# '/Users/abhimhatre/anaconda_projects/12531da2-1f80-4a1e-ad4d-5d1bcd476f3f'
